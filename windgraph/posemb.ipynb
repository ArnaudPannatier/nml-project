# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
plt.gray()
import numpy as np
import torch
from positional_encoding import SinCosPositionalEncoding

pe = SinCosPositionalEncoding(20)
x = torch.arange(0,200)
pe(x).shape
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# torch.Size([200, 40])

# %%
plt.imshow(pe(x).T.numpy())
plt.savefig("1dposenc.pdf")

# %%
X,Y = torch.meshgrid(x,x,indexing="ij")

# %%
fig, axs= plt.subplots(3,3)

pe_x, pe_y = pe(X), pe(Y)
print(pe_x.shape)

for ax, idx in zip(axs,[0,11,-1]):
    ax[0].imshow(pe_x[...,idx])
    ax[1].imshow(pe_y[...,idx])
    ax[2].imshow(pe_x[...,idx]+pe_y[...,idx])

axs[0,0].set_title("$pe(x)$")
axs[0,1].set_title("$pe(y)$")
axs[0,2].set_title("$pe(x)+pe(y)$")
plt.savefig("posenc.pdf")
# Out:
# torch.Size([200, 200, 40])
