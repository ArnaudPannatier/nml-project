# %%
import pandas as pd
df = pd.read_csv("results.csv")
df["model"] = df["model"].apply(lambda s: s[:-1])
df["date"] = pd.to_datetime(df["time"]).dt.day

# %%
df = df[df["date"]==7]

# %%
min_df = df.groupby(["model", "seed"]).min()
min_df.groupby("model").mean()
# Out:
#                    epoch  train    val  date
# model
# 3dsincos-1000N       0.0  0.524  1.027   7.0
# 3dsincos-100N        0.0  0.501  1.037   7.0
# 3dsincos-10N         0.0  0.511  1.068   7.0
# default-1000N        0.0  0.267  0.641   7.0
# default-100N         0.0  0.252  0.638   7.0
# default-10N          0.0  0.266  0.658   7.0
# edges-1000N-noemb    0.0  0.242  0.626   7.0
# edges-100N-noemb     0.0  0.250  0.627   7.0
# edges-10N-noemb      0.0  0.255  0.638   7.0
# edges-20N-noemb      0.0  0.250  0.620   7.0
# fd-1000N-noemb       0.0  0.251  0.617   7.0
# fd-100N-noemb        0.0  0.246  0.629   7.0
# fd-10N-noemb         0.0  0.270  0.641   7.0
# fd-20N-noemb         0.0  0.260  0.610   7.0
# noemb-1000N          0.0  0.204  0.651   7.0
# noemb-100N           0.0  0.220  0.665   7.0
# noemb-10N            0.0  0.236  0.680   7.0
# sincos-1000N         0.0  0.240  0.635   7.0
# sincos-100N          0.0  0.245  0.628   7.0
# sincos-10N           0.0  0.266  0.649   7.0

# %%
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
min_df.groupby("model").std()
# Out:
#                    epoch  train  val  date
# model
# 3dsincos-1000N      0.00   0.04 0.02  0.00
# 3dsincos-100N       0.00   0.04 0.03  0.00
# 3dsincos-10N        0.00   0.07 0.07  0.00
# default-1000N       0.00   0.02 0.03  0.00
# default-100N        0.00   0.03 0.01  0.00
# default-10N         0.00   0.02 0.01  0.00
# edges-1000N-noemb   0.00   0.03 0.01  0.00
# edges-100N-noemb    0.00   0.04 0.01  0.00
# edges-10N-noemb     0.00   0.01 0.02  0.00
# edges-20N-noemb      NaN    NaN  NaN   NaN
# fd-1000N-noemb      0.00   0.04 0.01  0.00
# fd-100N-noemb       0.00   0.03 0.01  0.00
# fd-10N-noemb        0.00   0.03 0.02  0.00
# fd-20N-noemb         NaN    NaN  NaN   NaN
# noemb-1000N         0.00   0.01 0.01  0.00
# noemb-100N          0.00   0.02 0.02  0.00
# noemb-10N           0.00   0.01 0.01  0.00
# sincos-1000N        0.00   0.02 0.01  0.00
# sincos-100N         0.00   0.04 0.01  0.00
# sincos-10N          0.00   0.03 0.02  0.00
